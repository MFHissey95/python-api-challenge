# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import json
import gmaps
import os

# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
#Call path to csv 
city_data = "./output_data/cities.csv"
# Read Cities Data File and store into Pandas Data Frames
city_df = pd.read_csv(city_data)
city_df.head(5)
# Out:
#    Unnamed: 0          City  Cloudiness Country        Date  Humidity    Lat  \
# 0           0  punta arenas          75      PH  1573691595        74  14.18
# 1           1    codrington          90      AU  1573691596        39 -28.95
# 2           2       ushuaia          20      AR  1573691596        66 -54.81
# 3           3      bagdarin          92      RU  1573691596        83  54.44
# 4           4     chandbali           0      IN  1573691596        71  20.77
#
#       Lng  Max Temp  Wind Speed
# 0  121.12     80.60        5.82
# 1  153.24     78.80        5.82
# 2  -68.31     51.80        2.73
# 3  113.59    -17.04        4.00
# 4   86.74     65.39        3.85

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
# Configure gmaps with API key
gmaps.configure(api_key=g_key)

# Store 'Lat' and 'Lng' into  locations 
locations = city_df[["Lat", "Lng"]].astype(float)

# Convert Poverty Rate to float and store
humidity = city_df["Humidity"].astype(float)

# %%
fig = gmaps.figure()

heat_layer = gmaps.heatmap_layer(locations, weights=humidity, 
                                 dissipating=False, max_intensity=100,
                                 point_radius = 1)

fig.add_layer(heat_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
#Conditions to meet A max temperature lower than 80 degrees but higher than 70, Wind speed less than 10 mph, zero cloudiness

# Create variable with TRUE if age is greater than 50
temp = city_df['Max Temp'] < 75
wind = city_df['Wind Speed'] < 5
clouds = city_df['Cloudiness'] < .1
humidity = city_df['Humidity'] < 60

hotel_df = city_df[temp & wind & clouds & humidity]
hotel_df.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)

hotel_df
# Out:
#      Unnamed: 0       City  Cloudiness Country        Date  Humidity    Lat  \
# 113         113    jiuquan           0      CN  1573691660        16  39.73
# 144         144    zhangye           0      CN  1573691680        18  38.94
# 226         226       gizo           0      IL  1573691720        56  31.80
# 253         253     kashan           0      IR  1573691730        30  33.99
# 308         308  grindavik           0      IS  1573691758        54  63.84
# 382         382    huanren           0      CN  1573691799        44  41.26
# 399         399     batken           0      KG  1573691804        35  40.06
# 436         436     haimen           0      CN  1573691831        47  31.87
# 438         438  sanmenxia           0      CN  1573691831        46  34.77
# 515         515     gerash           0      IR  1573691865        35  27.67
#
#         Lng  Max Temp  Wind Speed
# 113   98.49     26.38        3.44
# 144  100.46     27.99        4.25
# 226   34.94     71.60        4.70
# 253   51.44     42.80        2.24
# 308  -22.43     32.00        3.36
# 382  125.37     13.60        4.36
# 399   70.82     34.50        3.53
# 436  121.18     53.19        0.67
# 438  111.19     42.49        1.63
# 515   54.14     42.80        2.35

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
hotel_df['Hotel Name']= ""
hotel_df
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#      Unnamed: 0       City  Cloudiness Country        Date  Humidity    Lat  \
# 113         113    jiuquan           0      CN  1573691660        16  39.73
# 144         144    zhangye           0      CN  1573691680        18  38.94
# 226         226       gizo           0      IL  1573691720        56  31.80
# 253         253     kashan           0      IR  1573691730        30  33.99
# 308         308  grindavik           0      IS  1573691758        54  63.84
# 382         382    huanren           0      CN  1573691799        44  41.26
# 399         399     batken           0      KG  1573691804        35  40.06
# 436         436     haimen           0      CN  1573691831        47  31.87
# 438         438  sanmenxia           0      CN  1573691831        46  34.77
# 515         515     gerash           0      IR  1573691865        35  27.67
#
#         Lng  Max Temp  Wind Speed Hotel Name
# 113   98.49     26.38        3.44
# 144  100.46     27.99        4.25
# 226   34.94     71.60        4.70
# 253   51.44     42.80        2.24
# 308  -22.43     32.00        3.36
# 382  125.37     13.60        4.36
# 399   70.82     34.50        3.53
# 436  121.18     53.19        0.67
# 438  111.19     42.49        1.63
# 515   54.14     42.80        2.35

# %%
# geocoordinates
target_coordinates = "39.73,98.48"
target_radius = 5000
target_type = "lodging"

# set up a parameters dictionary
params = {
    "location": target_coordinates,
    "radius": target_radius,
    "type": target_type,
    "key": g_key
}

# base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?"
response = requests.get(base_url, params=params)
places_data = response.json()
hotel_name = places_data["results"][0]["name"]

hotel_df.loc[[113], 'Hotel Name'] = hotel_name
hotel_df
# Out:
#      Unnamed: 0       City  Cloudiness Country        Date  Humidity    Lat  \
# 113         113    jiuquan           0      CN  1573691660        16  39.73
# 144         144    zhangye           0      CN  1573691680        18  38.94
# 226         226       gizo           0      IL  1573691720        56  31.80
# 253         253     kashan           0      IR  1573691730        30  33.99
# 308         308  grindavik           0      IS  1573691758        54  63.84
# 382         382    huanren           0      CN  1573691799        44  41.26
# 399         399     batken           0      KG  1573691804        35  40.06
# 436         436     haimen           0      CN  1573691831        47  31.87
# 438         438  sanmenxia           0      CN  1573691831        46  34.77
# 515         515     gerash           0      IR  1573691865        35  27.67
#
#         Lng  Max Temp  Wind Speed     Hotel Name
# 113   98.49     26.38        3.44  Jiuquan Hotel
# 144  100.46     27.99        4.25
# 226   34.94     71.60        4.70
# 253   51.44     42.80        2.24
# 308  -22.43     32.00        3.36
# 382  125.37     13.60        4.36
# 399   70.82     34.50        3.53
# 436  121.18     53.19        0.67
# 438  111.19     42.49        1.63
# 515   54.14     42.80        2.35

# %%
# geocoordinates
target_coordinates = "38.94,100.46"
target_radius = 5000
target_type = "lodging"

# set up a parameters dictionary
params = {
    "location": target_coordinates,
    "radius": target_radius,
    "type": target_type,
    "key": g_key
}

# base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?"
response = requests.get(base_url, params=params)
places_data = response.json()
hotel_name = places_data["results"][0]["name"]

hotel_df.loc[[144], 'Hotel Name'] = hotel_name
hotel_df
# Out:
#      Unnamed: 0       City  Cloudiness Country        Date  Humidity    Lat  \
# 113         113    jiuquan           0      CN  1573691660        16  39.73
# 144         144    zhangye           0      CN  1573691680        18  38.94
# 226         226       gizo           0      IL  1573691720        56  31.80
# 253         253     kashan           0      IR  1573691730        30  33.99
# 308         308  grindavik           0      IS  1573691758        54  63.84
# 382         382    huanren           0      CN  1573691799        44  41.26
# 399         399     batken           0      KG  1573691804        35  40.06
# 436         436     haimen           0      CN  1573691831        47  31.87
# 438         438  sanmenxia           0      CN  1573691831        46  34.77
# 515         515     gerash           0      IR  1573691865        35  27.67
#
#         Lng  Max Temp  Wind Speed                  Hotel Name
# 113   98.49     26.38        3.44               Jiuquan Hotel
# 144  100.46     27.99        4.25  Zhangye Lvzhou Holiday Inn
# 226   34.94     71.60        4.70
# 253   51.44     42.80        2.24
# 308  -22.43     32.00        3.36
# 382  125.37     13.60        4.36
# 399   70.82     34.50        3.53
# 436  121.18     53.19        0.67
# 438  111.19     42.49        1.63
# 515   54.14     42.80        2.35

# %%
# geocoordinates
target_coordinates = "31.80,34.94"
target_radius = 5000
target_type = "lodging"

# set up a parameters dictionary
params = {
    "location": target_coordinates,
    "radius": target_radius,
    "type": target_type,
    "key": g_key
}

# base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?"
response = requests.get(base_url, params=params)
places_data = response.json()
hotel_name = places_data["results"][0]["name"]

hotel_df.loc[[226], 'Hotel Name'] = hotel_name
hotel_df
# Out:
#      Unnamed: 0       City  Cloudiness Country        Date  Humidity    Lat  \
# 113         113    jiuquan           0      CN  1573691660        16  39.73
# 144         144    zhangye           0      CN  1573691680        18  38.94
# 226         226       gizo           0      IL  1573691720        56  31.80
# 253         253     kashan           0      IR  1573691730        30  33.99
# 308         308  grindavik           0      IS  1573691758        54  63.84
# 382         382    huanren           0      CN  1573691799        44  41.26
# 399         399     batken           0      KG  1573691804        35  40.06
# 436         436     haimen           0      CN  1573691831        47  31.87
# 438         438  sanmenxia           0      CN  1573691831        46  34.77
# 515         515     gerash           0      IR  1573691865        35  27.67
#
#         Lng  Max Temp  Wind Speed                  Hotel Name
# 113   98.49     26.38        3.44               Jiuquan Hotel
# 144  100.46     27.99        4.25  Zhangye Lvzhou Holiday Inn
# 226   34.94     71.60        4.70                בקתות לשקיעה
# 253   51.44     42.80        2.24
# 308  -22.43     32.00        3.36
# 382  125.37     13.60        4.36
# 399   70.82     34.50        3.53
# 436  121.18     53.19        0.67
# 438  111.19     42.49        1.63
# 515   54.14     42.80        2.35

# %%
# geocoordinates
target_coordinates = "33.99,51.44"
target_radius = 5000
target_type = "lodging"

# set up a parameters dictionary
params = {
    "location": target_coordinates,
    "radius": target_radius,
    "type": target_type,
    "key": g_key
}

# base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?"
response = requests.get(base_url, params=params)
places_data = response.json()
hotel_name = places_data["results"][0]["name"]

hotel_df.loc[[253], 'Hotel Name'] = hotel_name
hotel_df
# Out:
#      Unnamed: 0       City  Cloudiness Country        Date  Humidity    Lat  \
# 113         113    jiuquan           0      CN  1573691660        16  39.73
# 144         144    zhangye           0      CN  1573691680        18  38.94
# 226         226       gizo           0      IL  1573691720        56  31.80
# 253         253     kashan           0      IR  1573691730        30  33.99
# 308         308  grindavik           0      IS  1573691758        54  63.84
# 382         382    huanren           0      CN  1573691799        44  41.26
# 399         399     batken           0      KG  1573691804        35  40.06
# 436         436     haimen           0      CN  1573691831        47  31.87
# 438         438  sanmenxia           0      CN  1573691831        46  34.77
# 515         515     gerash           0      IR  1573691865        35  27.67
#
#         Lng  Max Temp  Wind Speed                               Hotel Name
# 113   98.49     26.38        3.44                            Jiuquan Hotel
# 144  100.46     27.99        4.25               Zhangye Lvzhou Holiday Inn
# 226   34.94     71.60        4.70                             בקתות לשקיעה
# 253   51.44     42.80        2.24  Manouchehri Traditional House And Hotel
# 308  -22.43     32.00        3.36
# 382  125.37     13.60        4.36
# 399   70.82     34.50        3.53
# 436  121.18     53.19        0.67
# 438  111.19     42.49        1.63
# 515   54.14     42.80        2.35

# %%
# geocoordinates
target_coordinates = "33.99,51.44"
target_radius = 5000
target_type = "lodging"

# set up a parameters dictionary
params = {
    "location": target_coordinates,
    "radius": target_radius,
    "type": target_type,
    "key": g_key
}

# base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?"
response = requests.get(base_url, params=params)
places_data = response.json()
hotel_name = places_data["results"][0]["name"]

hotel_df.loc[[253], 'Hotel Name'] = hotel_name
hotel_df

# %%
# geocoordinates
target_coordinates = "63.84,-22.43"
target_radius = 5000
target_type = "lodging"

# set up a parameters dictionary
params = {
    "location": target_coordinates,
    "radius": target_radius,
    "type": target_type,
    "key": g_key
}

# base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?"
response = requests.get(base_url, params=params)
places_data = response.json()
hotel_name = places_data["results"][0]["name"]

hotel_df.loc[[308], 'Hotel Name'] = hotel_name
hotel_df
# Out:
#      Unnamed: 0       City  Cloudiness Country        Date  Humidity    Lat  \
# 113         113    jiuquan           0      CN  1573691660        16  39.73
# 144         144    zhangye           0      CN  1573691680        18  38.94
# 226         226       gizo           0      IL  1573691720        56  31.80
# 253         253     kashan           0      IR  1573691730        30  33.99
# 308         308  grindavik           0      IS  1573691758        54  63.84
# 382         382    huanren           0      CN  1573691799        44  41.26
# 399         399     batken           0      KG  1573691804        35  40.06
# 436         436     haimen           0      CN  1573691831        47  31.87
# 438         438  sanmenxia           0      CN  1573691831        46  34.77
# 515         515     gerash           0      IR  1573691865        35  27.67
#
#         Lng  Max Temp  Wind Speed                               Hotel Name
# 113   98.49     26.38        3.44                            Jiuquan Hotel
# 144  100.46     27.99        4.25               Zhangye Lvzhou Holiday Inn
# 226   34.94     71.60        4.70                             בקתות לשקיעה
# 253   51.44     42.80        2.24  Manouchehri Traditional House And Hotel
# 308  -22.43     32.00        3.36    Northern Light Inn & Max's Restaurant
# 382  125.37     13.60        4.36
# 399   70.82     34.50        3.53
# 436  121.18     53.19        0.67
# 438  111.19     42.49        1.63
# 515   54.14     42.80        2.35

# %%
# geocoordinates
target_coordinates = "41.26,125.37"
target_radius = 5000
target_type = "lodging"

# set up a parameters dictionary
params = {
    "location": target_coordinates,
    "radius": target_radius,
    "type": target_type,
    "key": g_key
}

# base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?"
response = requests.get(base_url, params=params)
places_data = response.json()
hotel_name = places_data["results"][0]["name"]

hotel_df.loc[[382], 'Hotel Name'] = hotel_name
hotel_df
# Out:
#      Unnamed: 0       City  Cloudiness Country        Date  Humidity    Lat  \
# 113         113    jiuquan           0      CN  1573691660        16  39.73
# 144         144    zhangye           0      CN  1573691680        18  38.94
# 226         226       gizo           0      IL  1573691720        56  31.80
# 253         253     kashan           0      IR  1573691730        30  33.99
# 308         308  grindavik           0      IS  1573691758        54  63.84
# 382         382    huanren           0      CN  1573691799        44  41.26
# 399         399     batken           0      KG  1573691804        35  40.06
# 436         436     haimen           0      CN  1573691831        47  31.87
# 438         438  sanmenxia           0      CN  1573691831        46  34.77
# 515         515     gerash           0      IR  1573691865        35  27.67
#
#         Lng  Max Temp  Wind Speed                               Hotel Name
# 113   98.49     26.38        3.44                            Jiuquan Hotel
# 144  100.46     27.99        4.25               Zhangye Lvzhou Holiday Inn
# 226   34.94     71.60        4.70                             בקתות לשקיעה
# 253   51.44     42.80        2.24  Manouchehri Traditional House And Hotel
# 308  -22.43     32.00        3.36    Northern Light Inn & Max's Restaurant
# 382  125.37     13.60        4.36             Dynasty Wunvshan Ice Chateau
# 399   70.82     34.50        3.53
# 436  121.18     53.19        0.67
# 438  111.19     42.49        1.63
# 515   54.14     42.80        2.35

# %%
# geocoordinates
target_coordinates = "40.06,70.82"
target_radius = 5000
target_type = "lodging"

# set up a parameters dictionary
params = {
    "location": target_coordinates,
    "radius": target_radius,
    "type": target_type,
    "key": g_key
}

# base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?"
response = requests.get(base_url, params=params)
places_data = response.json()
hotel_name = places_data["results"][0]["name"]

hotel_df.loc[[399], 'Hotel Name'] = hotel_name
hotel_df
# Out:
#      Unnamed: 0       City  Cloudiness Country        Date  Humidity    Lat  \
# 113         113    jiuquan           0      CN  1573691660        16  39.73
# 144         144    zhangye           0      CN  1573691680        18  38.94
# 226         226       gizo           0      IL  1573691720        56  31.80
# 253         253     kashan           0      IR  1573691730        30  33.99
# 308         308  grindavik           0      IS  1573691758        54  63.84
# 382         382    huanren           0      CN  1573691799        44  41.26
# 399         399     batken           0      KG  1573691804        35  40.06
# 436         436     haimen           0      CN  1573691831        47  31.87
# 438         438  sanmenxia           0      CN  1573691831        46  34.77
# 515         515     gerash           0      IR  1573691865        35  27.67
#
#         Lng  Max Temp  Wind Speed                               Hotel Name
# 113   98.49     26.38        3.44                            Jiuquan Hotel
# 144  100.46     27.99        4.25               Zhangye Lvzhou Holiday Inn
# 226   34.94     71.60        4.70                             בקתות לשקיעה
# 253   51.44     42.80        2.24  Manouchehri Traditional House And Hotel
# 308  -22.43     32.00        3.36    Northern Light Inn & Max's Restaurant
# 382  125.37     13.60        4.36             Dynasty Wunvshan Ice Chateau
# 399   70.82     34.50        3.53                Gostinitsa "Altyn-Beshik"
# 436  121.18     53.19        0.67
# 438  111.19     42.49        1.63
# 515   54.14     42.80        2.35

# %%
# geocoordinates
target_coordinates = "31.87,121.18"
target_radius = 5000
target_type = "lodging"

# set up a parameters dictionary
params = {
    "location": target_coordinates,
    "radius": target_radius,
    "type": target_type,
    "key": g_key
}

# base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?"
response = requests.get(base_url, params=params)
places_data = response.json()
hotel_name = places_data["results"][0]["name"]

hotel_df.loc[[436], 'Hotel Name'] = hotel_name
hotel_df
# Out:
#      Unnamed: 0       City  Cloudiness Country        Date  Humidity    Lat  \
# 113         113    jiuquan           0      CN  1573691660        16  39.73
# 144         144    zhangye           0      CN  1573691680        18  38.94
# 226         226       gizo           0      IL  1573691720        56  31.80
# 253         253     kashan           0      IR  1573691730        30  33.99
# 308         308  grindavik           0      IS  1573691758        54  63.84
# 382         382    huanren           0      CN  1573691799        44  41.26
# 399         399     batken           0      KG  1573691804        35  40.06
# 436         436     haimen           0      CN  1573691831        47  31.87
# 438         438  sanmenxia           0      CN  1573691831        46  34.77
# 515         515     gerash           0      IR  1573691865        35  27.67
#
#         Lng  Max Temp  Wind Speed                               Hotel Name
# 113   98.49     26.38        3.44                            Jiuquan Hotel
# 144  100.46     27.99        4.25               Zhangye Lvzhou Holiday Inn
# 226   34.94     71.60        4.70                             בקתות לשקיעה
# 253   51.44     42.80        2.24  Manouchehri Traditional House And Hotel
# 308  -22.43     32.00        3.36    Northern Light Inn & Max's Restaurant
# 382  125.37     13.60        4.36             Dynasty Wunvshan Ice Chateau
# 399   70.82     34.50        3.53                Gostinitsa "Altyn-Beshik"
# 436  121.18     53.19        0.67                                 Home Inn
# 438  111.19     42.49        1.63
# 515   54.14     42.80        2.35

# %%
# geocoordinates
target_coordinates = "34.77,111.19"
target_radius = 5000
target_type = "lodging"

# set up a parameters dictionary
params = {
    "location": target_coordinates,
    "radius": target_radius,
    "type": target_type,
    "key": g_key
}

# base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?"
response = requests.get(base_url, params=params)
places_data = response.json()
hotel_name = places_data["results"][0]["name"]

hotel_df.loc[[438], 'Hotel Name'] = hotel_name
hotel_df
# Out:
#      Unnamed: 0       City  Cloudiness Country        Date  Humidity    Lat  \
# 113         113    jiuquan           0      CN  1573691660        16  39.73
# 144         144    zhangye           0      CN  1573691680        18  38.94
# 226         226       gizo           0      IL  1573691720        56  31.80
# 253         253     kashan           0      IR  1573691730        30  33.99
# 308         308  grindavik           0      IS  1573691758        54  63.84
# 382         382    huanren           0      CN  1573691799        44  41.26
# 399         399     batken           0      KG  1573691804        35  40.06
# 436         436     haimen           0      CN  1573691831        47  31.87
# 438         438  sanmenxia           0      CN  1573691831        46  34.77
# 515         515     gerash           0      IR  1573691865        35  27.67
#
#         Lng  Max Temp  Wind Speed                               Hotel Name
# 113   98.49     26.38        3.44                            Jiuquan Hotel
# 144  100.46     27.99        4.25               Zhangye Lvzhou Holiday Inn
# 226   34.94     71.60        4.70                             בקתות לשקיעה
# 253   51.44     42.80        2.24  Manouchehri Traditional House And Hotel
# 308  -22.43     32.00        3.36    Northern Light Inn & Max's Restaurant
# 382  125.37     13.60        4.36             Dynasty Wunvshan Ice Chateau
# 399   70.82     34.50        3.53                Gostinitsa "Altyn-Beshik"
# 436  121.18     53.19        0.67                                 Home Inn
# 438  111.19     42.49        1.63                           Pengzhou Hotel
# 515   54.14     42.80        2.35

# %%
# geocoordinates
target_coordinates = "27.67,54.14"
target_radius = 5000
target_type = "lodging"

# set up a parameters dictionary
params = {
    "location": target_coordinates,
    "radius": target_radius,
    "type": target_type,
    "key": g_key
}

# base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?"
response = requests.get(base_url, params=params)
places_data = response.json()
hotel_name = places_data["results"][0]["name"]

hotel_df.loc[[515], 'Hotel Name'] = hotel_name
hotel_df
# Out:
#      Unnamed: 0       City  Cloudiness Country        Date  Humidity    Lat  \
# 113         113    jiuquan           0      CN  1573691660        16  39.73
# 144         144    zhangye           0      CN  1573691680        18  38.94
# 226         226       gizo           0      IL  1573691720        56  31.80
# 253         253     kashan           0      IR  1573691730        30  33.99
# 308         308  grindavik           0      IS  1573691758        54  63.84
# 382         382    huanren           0      CN  1573691799        44  41.26
# 399         399     batken           0      KG  1573691804        35  40.06
# 436         436     haimen           0      CN  1573691831        47  31.87
# 438         438  sanmenxia           0      CN  1573691831        46  34.77
# 515         515     gerash           0      IR  1573691865        35  27.67
#
#         Lng  Max Temp  Wind Speed                               Hotel Name
# 113   98.49     26.38        3.44                            Jiuquan Hotel
# 144  100.46     27.99        4.25               Zhangye Lvzhou Holiday Inn
# 226   34.94     71.60        4.70                             בקתות לשקיעה
# 253   51.44     42.80        2.24  Manouchehri Traditional House And Hotel
# 308  -22.43     32.00        3.36    Northern Light Inn & Max's Restaurant
# 382  125.37     13.60        4.36             Dynasty Wunvshan Ice Chateau
# 399   70.82     34.50        3.53                Gostinitsa "Altyn-Beshik"
# 436  121.18     53.19        0.67                                 Home Inn
# 438  111.19     42.49        1.63                           Pengzhou Hotel
# 515   54.14     42.80        2.35                                Chelpasin

# %%
# geocoordinates
target_coordinates = "39.73, 98.49"
target_radius = 5000
target_type = "lodging"

# set up a parameters dictionary
params = {
    "location": target_coordinates,
    "radius": target_radius,
    "type": target_type,
    "key": g_key
}

# base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?"

response = requests.get(base_url, params=params)
places_data = response.json()
print(json.dumps(places_data, indent=4, sort_keys=True))
# Out:
# {
#     "html_attributions": [],
#     "next_page_token": "CqQCHgEAACmY2RsphmVhxdsgQCl5BxtFS7uDEqv9r7Pjl8fEzM_fV4iQsQdb8vnH4q5jyyR-P7dXVYhWAQ1ONHdUM_dEuVTU079h34Xk6Kv0cDN0p_ikB6qpK-9bvoZkN9wJTevb-jRRxFBVNA75Woy7of0JWB6YlDKJHb-6hifDogx4RKWRZ-SYL7aWhtldVmtJu0Cvyn6LStlv4jp8aVKXAbiSSKhZIwGnqX1vylWgzH6lGBOchFce0j6Ec7N4_22-2TCwLUYoUmoZ8nM60NgkBk4pN54xr2R-OdM3uhuNw0RS1wKlKUix5NH0fCJ5CLhYY9PELdHE1mPNy1-k8u-uh0bvz0uNnshFVYBtFt1aD7_kQDpTVwBY5UXlMMP7GDIB32iwJhIQYqmLS7QmMWa8GuFF2UgRthoUqMradsO7jTl4IbPW0Xu5DPtZkJg",
#     "results": [
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 39.737397,
#                     "lng": 98.507802
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 39.7387206802915,
#                         "lng": 98.5091908302915
#                     },
#                     "southwest": {
#                         "lat": 39.7360227197085,
#                         "lng": 98.5064928697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "21395056ea11ca61aff284297f39aaed2ac83ca7",
#             "name": "Jiuquan Hotel",
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/114917636806577300487/photos\">\u674e\u653f\u8aed</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAtcWU6_EizqaiC2ARNUvFaqb9qlyFBeuJ84x8dAGX2SID9SX0EC2foIIVIeK9S5aq8wMhR_x2iwpHQoF5Jt1UTZjpit5DWXUjV9USY5B7YDxw-FaFE3NCPFYBFrjmPoVGEhCc4QdyAchj1ZtmCGoxN6WAGhRPhGGfs_qonPyWw73CJRiExiZZ7w",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJ43vuP5bUyTcRsvlEhAdogOQ",
#             "plus_code": {
#                 "compound_code": "PGP5+X4 Xinan Street Residential District, Suzhou, Jiuquan, Gansu, China",
#                 "global_code": "8MFWPGP5+X4"
#             },
#             "rating": 3.9,
#             "reference": "ChIJ43vuP5bUyTcRsvlEhAdogOQ",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 51,
#             "vicinity": "33 Jiefang Road, Suzhou, Jiuquan"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 39.73719559999999,
#                     "lng": 98.50161159999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 39.73858773029149,
#                         "lng": 98.50285103029151
#                     },
#                     "southwest": {
#                         "lat": 39.73588976970849,
#                         "lng": 98.5001530697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "0a4e4e0b8ffcd7677a551848b0ec2babe96b1646",
#             "name": "Jiuquan Xin Guang Ming Hotel",
#             "photos": [
#                 {
#                     "height": 1688,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/107515584349499833414/photos\">\u5409\u6613</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAshPUFnx6GRhfKinh7cmYYTi8bza8F7oPq3g72pqZFrACIMH6YtyCupGriIrlw2SQcVNreE87j2JEhqZSUlCzVqx56DYsffhb6GXVD1woCSK67wPXBn4SNPcfpo-w21pkEhBviOCyqkbGfYQDyzahLjP7GhQttcI5JN60JL6vJ4S2MGeHNb49TA",
#                     "width": 2999
#                 }
#             ],
#             "place_id": "ChIJkVXjELzUyTcRC3r-lSyQpqg",
#             "plus_code": {
#                 "compound_code": "PGP2+VJ Xinan Street Residential District, Suzhou, Jiuquan, Gansu, China",
#                 "global_code": "8MFWPGP2+VJ"
#             },
#             "reference": "ChIJkVXjELzUyTcRC3r-lSyQpqg",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "\u8083\u5dde\u533a\u76d8\u65cb\u4e2d\u8def18\u53f7, Jiuquan"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 39.73603000000001,
#                     "lng": 98.51322599999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 39.7373577802915,
#                         "lng": 98.51456963029149
#                     },
#                     "southwest": {
#                         "lat": 39.7346598197085,
#                         "lng": 98.51187166970848
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "5f51a0304ef6657d20cdc9baa5bced288efc0d0d",
#             "name": "Vatica GanSu Jiuquan Eastern Bus Station Hotel",
#             "place_id": "ChIJ760BZ5HUyTcRk1tKIb1qMjk",
#             "plus_code": {
#                 "compound_code": "PGP7+C7 Xinan Street Residential District, Suzhou, Jiuquan, Gansu, China",
#                 "global_code": "8MFWPGP7+C7"
#             },
#             "reference": "ChIJ760BZ5HUyTcRk1tKIb1qMjk",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "\u9152\u6cc9\u76d8\u65cb\u4e1c\u8def22\u53f7, Jiuquan"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 39.743196,
#                     "lng": 98.51066999999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 39.74448118029149,
#                         "lng": 98.5120102302915
#                     },
#                     "southwest": {
#                         "lat": 39.74178321970849,
#                         "lng": 98.50931226970849
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "4c02fe664af23b72369aff50d06f09b119572234",
#             "name": "\u597d\u5982\u5bb6\u5feb\u6377\u9152\u5e97",
#             "place_id": "ChIJF_kgnJnUyTcRy0tvoOVyc5M",
#             "plus_code": {
#                 "compound_code": "PGV6+77 Xibeijie Residential District, Suzhou, Jiuquan, Gansu, China",
#                 "global_code": "8MFWPGV6+77"
#             },
#             "reference": "ChIJF_kgnJnUyTcRy0tvoOVyc5M",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Suzhou, Jiuquan"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 39.747601,
#                     "lng": 98.508814
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 39.7489509802915,
#                         "lng": 98.5101553802915
#                     },
#                     "southwest": {
#                         "lat": 39.7462530197085,
#                         "lng": 98.50745741970849
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "9bc55daa3105ebc3221847f5d5603a22b26e5346",
#             "name": "Jiuquan Oriental International Hotel",
#             "photos": [
#                 {
#                     "height": 2322,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/104861816190703098482/photos\">Sergey Semenovich</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA3GRM9IIpjCx_4qJHsCXiocgtfMSw9mbtv-H_F_IIxgsgcUH9XuYiaeIJJRBXnwOgHwLpRVSrZ4R4Ax62n70AemuMEOUe40VwEAgqTVBNb1sG4QG2HC8HC6nogeDN3jZkEhDo1zyIiZ9CEKM6EKzvphVQGhTZwN4LBvTpfxniTuhaGfM4XS6fOg",
#                     "width": 4128
#                 }
#             ],
#             "place_id": "ChIJZaVaHp_UyTcRLjx3Q51-hSg",
#             "plus_code": {
#                 "compound_code": "PGX5+2G Xibeijie Residential District, Suzhou, Jiuquan, Gansu, China",
#                 "global_code": "8MFWPGX5+2G"
#             },
#             "rating": 4,
#             "reference": "ChIJZaVaHp_UyTcRLjx3Q51-hSg",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1,
#             "vicinity": "6 Cangmen Street, Suzhou, Jiuquan"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 39.735066,
#                     "lng": 98.494908
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 39.7364615302915,
#                         "lng": 98.4960044802915
#                     },
#                     "southwest": {
#                         "lat": 39.7337635697085,
#                         "lng": 98.49330651970848
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "fc04a05adb54c4a4875099185de013bd1346ab36",
#             "name": "Century Hotel",
#             "place_id": "ChIJVcGmZLfUyTcRol5FIcnDluA",
#             "plus_code": {
#                 "compound_code": "PFPV+2X Xinan Street Residential District, Suzhou, Jiuquan, Gansu, China",
#                 "global_code": "8MFWPFPV+2X"
#             },
#             "reference": "ChIJVcGmZLfUyTcRol5FIcnDluA",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "53 Century Avenue, Suzhou, Jiuquan"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 39.7420602,
#                     "lng": 98.51002079999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 39.7434061302915,
#                         "lng": 98.51141253029151
#                     },
#                     "southwest": {
#                         "lat": 39.7407081697085,
#                         "lng": 98.50871456970849
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "db2ee9aaf64cc8c4c558835d0e25af2846e17495",
#             "name": "Julong Hostel",
#             "place_id": "ChIJ38ojx5nUyTcRqWGQTgHuijY",
#             "plus_code": {
#                 "compound_code": "PGR6+R2 Xinan Street Residential District, Suzhou, Jiuquan, Gansu, China",
#                 "global_code": "8MFWPGR6+R2"
#             },
#             "reference": "ChIJ38ojx5nUyTcRqWGQTgHuijY",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "South Street, Suzhou, Jiuquan"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 39.7382204,
#                     "lng": 98.51434789999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 39.7396030302915,
#                         "lng": 98.5157352802915
#                     },
#                     "southwest": {
#                         "lat": 39.7369050697085,
#                         "lng": 98.51303731970849
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "0186716a3fc6903eec097293d834354ba6f0ea40",
#             "name": "Education Hotel",
#             "place_id": "ChIJxx6z_5DUyTcR1baSFvu5LDc",
#             "plus_code": {
#                 "compound_code": "PGQ7+7P Xinan Street Residential District, Suzhou, Jiuquan, Gansu, China",
#                 "global_code": "8MFWPGQ7+7P"
#             },
#             "reference": "ChIJxx6z_5DUyTcR1baSFvu5LDc",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "South Ring Road East, Suzhou, Jiuquan"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 39.729919,
#                     "lng": 98.497078
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 39.7312655802915,
#                         "lng": 98.4984269802915
#                     },
#                     "southwest": {
#                         "lat": 39.7285676197085,
#                         "lng": 98.49572901970849
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "d635fcb33922fd33e7438ab62d9235a5726a6e39",
#             "name": "Green Tree Inn Jiuquan Century Plaza Hotel",
#             "place_id": "ChIJY6ilu8fUyTcR7DvYMjMtpws",
#             "plus_code": {
#                 "compound_code": "PFHW+XR Xinan Street Residential District, Suzhou, Jiuquan, Gansu, China",
#                 "global_code": "8MFWPFHW+XR"
#             },
#             "rating": 5,
#             "reference": "ChIJY6ilu8fUyTcR7DvYMjMtpws",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1,
#             "vicinity": "Building 8, Hongyang Plaza, BaoQuandong Road, \u9152\u6cc9\u5e02"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 39.746737,
#                     "lng": 98.5082
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 39.74802553029149,
#                         "lng": 98.5095299802915
#                     },
#                     "southwest": {
#                         "lat": 39.74532756970849,
#                         "lng": 98.5068320197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "85cd36e87583f5d78f60af07b192944b8f9405ab",
#             "name": "Jiuquan Hangtian Hotel",
#             "place_id": "ChIJS2wXMJ_UyTcR_-fnCT0BhEI",
#             "plus_code": {
#                 "compound_code": "PGW5+M7 Xibeijie Residential District, Suzhou, Jiuquan, Gansu, China",
#                 "global_code": "8MFWPGW5+M7"
#             },
#             "reference": "ChIJS2wXMJ_UyTcR_-fnCT0BhEI",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "42 Cangmen Street, Suzhou, Jiuquan"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 39.745185,
#                     "lng": 98.499459
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 39.74662388029149,
#                         "lng": 98.5008186802915
#                     },
#                     "southwest": {
#                         "lat": 39.7439259197085,
#                         "lng": 98.4981207197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "52de411bbe08182ef003cee2dc979f4ddc0eefe8",
#             "name": "Home Inn",
#             "place_id": "ChIJ1xCCaaTUyTcRpzwyspkCZ_k",
#             "plus_code": {
#                 "compound_code": "PFWX+3Q Xibeijie Residential District, Suzhou, Jiuquan, Gansu, China",
#                 "global_code": "8MFWPFWX+3Q"
#             },
#             "reference": "ChIJ1xCCaaTUyTcRpzwyspkCZ_k",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "40-1 West Street, Jiuquan"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 39.739826,
#                     "lng": 98.50806299999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 39.7412702802915,
#                         "lng": 98.5094295302915
#                     },
#                     "southwest": {
#                         "lat": 39.7385723197085,
#                         "lng": 98.50673156970849
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "3281ed9305d6676b36453a90374d72bda44036db",
#             "name": "Hanting Hotel",
#             "place_id": "ChIJV5AxlpfUyTcRSZh3EYqrhZk",
#             "plus_code": {
#                 "compound_code": "PGQ5+W6 Xinan Street Residential District, Suzhou, Jiuquan, Gansu, China",
#                 "global_code": "8MFWPGQ5+W6"
#             },
#             "reference": "ChIJV5AxlpfUyTcRSZh3EYqrhZk",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "10 Tuanjie West Road, Suzhou, Jiuquan"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 39.736122,
#                     "lng": 98.511469
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 39.7375520802915,
#                         "lng": 98.5128375302915
#                     },
#                     "southwest": {
#                         "lat": 39.7348541197085,
#                         "lng": 98.5101395697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "926cbcb06759b062fdbf3b3364d61287d33190c8",
#             "name": "Gemdale Hotel",
#             "place_id": "ChIJ2xtFrJbUyTcRY_iS7mVVkdM",
#             "plus_code": {
#                 "compound_code": "PGP6+CH Xinan Street Residential District, Suzhou, Jiuquan, Gansu, China",
#                 "global_code": "8MFWPGP6+CH"
#             },
#             "reference": "ChIJ2xtFrJbUyTcRY_iS7mVVkdM",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "8 Panxuan East Road, Suzhou, Jiuquan"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 39.739465,
#                     "lng": 98.515383
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 39.7407482302915,
#                         "lng": 98.5167150802915
#                     },
#                     "southwest": {
#                         "lat": 39.7380502697085,
#                         "lng": 98.5140171197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "79985107bfba742dd38e05e272fb0246542acc2a",
#             "name": "Pai Hotel",
#             "place_id": "ChIJx0BraZDUyTcRXxKQ_IRW2ds",
#             "plus_code": {
#                 "compound_code": "PGQ8+Q5 Dongnan Street Residential District, Suzhou, Jiuquan, Gansu, China",
#                 "global_code": "8MFWPGQ8+Q5"
#             },
#             "reference": "ChIJx0BraZDUyTcRXxKQ_IRW2ds",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "\u5efa\u8bbe\u8def8\u53f7CN \u9152\u6cc9"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 39.734697,
#                     "lng": 98.518812
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 39.7361258302915,
#                         "lng": 98.5202209302915
#                     },
#                     "southwest": {
#                         "lat": 39.7334278697085,
#                         "lng": 98.5175229697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "ac93026bacf23ed2b427e88e1741b6d6ecb393b9",
#             "name": "Homeland Hostel",
#             "place_id": "ChIJT2Rn3I3UyTcR7hSr1O76E_Y",
#             "plus_code": {
#                 "compound_code": "PGM9+VG Dongguan Street Residential District, Suzhou, Jiuquan, Gansu, China",
#                 "global_code": "8MFWPGM9+VG"
#             },
#             "reference": "ChIJT2Rn3I3UyTcR7hSr1O76E_Y",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Qilian Road, Suzhou, Jiuquan"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 39.741089,
#                     "lng": 98.519702
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 39.74244963029149,
#                         "lng": 98.5209402802915
#                     },
#                     "southwest": {
#                         "lat": 39.7397516697085,
#                         "lng": 98.51824231970849
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "3e8c80494958fdb4865f1b58cd1e8925d4a00eec",
#             "name": "Thank You Express Hotel",
#             "place_id": "ChIJO_uSdoXUyTcRQ0mnL93xjYM",
#             "plus_code": {
#                 "compound_code": "PGR9+CV Dongnan Street Residential District, Suzhou, Jiuquan, Gansu, China",
#                 "global_code": "8MFWPGR9+CV"
#             },
#             "reference": "ChIJO_uSdoXUyTcRQ0mnL93xjYM",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "East Ring Road South, Suzhou, Jiuquan"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 39.7472645,
#                     "lng": 98.49714770000001
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 39.7485973302915,
#                         "lng": 98.4984419302915
#                     },
#                     "southwest": {
#                         "lat": 39.7458993697085,
#                         "lng": 98.4957439697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "ba0d299f5f771179d7fb751543d60ab8c3adf8be",
#             "name": "China Jiuquan Satellite Fashe Center Office Hostel",
#             "place_id": "ChIJ7RKqcKbUyTcR7kepqgKVQG8",
#             "plus_code": {
#                 "compound_code": "PFWW+WV Xibeijie Residential District, Suzhou, Jiuquan, Gansu, China",
#                 "global_code": "8MFWPFWW+WV"
#             },
#             "reference": "ChIJ7RKqcKbUyTcR7kepqgKVQG8",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Xiongguan Road, Suzhou, Jiuquan"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 39.729612,
#                     "lng": 98.48959599999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 39.73095448029149,
#                         "lng": 98.49112308029149
#                     },
#                     "southwest": {
#                         "lat": 39.72825651970849,
#                         "lng": 98.48842511970848
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "9eebea7b299e6b30478e1e1e50fddc24336a1201",
#             "name": "Huicheng Hotel",
#             "photos": [
#                 {
#                     "height": 2322,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/117622060270816533349/photos\">\u0415\u043b\u0435\u043d\u0430 \u0421\u0442\u0430\u043d\u0451\u043d\u0438\u0441</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAyRJQzl2JCCQ45KcowlH2-ljaWaSiLyWJUzbwY802Z9EsYOmyCeMRKSFqHs0pDB2-P05VvWR71ZNiqpnLHjTqfMztoeeIcZlBI2LAdrpNLDBx-wseUvY3OM-7Jik1lTdlEhDq_1bDu5ofS_og4LgVIYzhGhTe0-fTMW-zdbt9K7fnoWqwRB-lLA",
#                     "width": 4128
#                 }
#             ],
#             "place_id": "ChIJZQEt1cvUyTcRh_45qKRuvKY",
#             "plus_code": {
#                 "compound_code": "PFHQ+RR Xifengzhen, Suzhou, Jiuquan, Gansu, China",
#                 "global_code": "8MFWPFHQ+RR"
#             },
#             "rating": 2,
#             "reference": "ChIJZQEt1cvUyTcRh_45qKRuvKY",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1,
#             "vicinity": "16 Mogao Road, Suzhou, Jiuquan"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 39.729245,
#                     "lng": 98.490161
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 39.7305981802915,
#                         "lng": 98.4913949302915
#                     },
#                     "southwest": {
#                         "lat": 39.7279002197085,
#                         "lng": 98.4886969697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "fd15d8bcc4cd4c199d6dd117a119c672b5010eba",
#             "name": "Baoquan Hotel",
#             "place_id": "ChIJT5jge8nUyTcRd6z5XvKdFaA",
#             "plus_code": {
#                 "compound_code": "PFHR+M3 Xifengzhen, Suzhou, Jiuquan, Gansu, China",
#                 "global_code": "8MFWPFHR+M3"
#             },
#             "reference": "ChIJT5jge8nUyTcRd6z5XvKdFaA",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Mogao Road, Suzhou, Jiuquan"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 39.728284,
#                     "lng": 98.49056
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 39.72964553029149,
#                         "lng": 98.49156533029151
#                     },
#                     "southwest": {
#                         "lat": 39.7269475697085,
#                         "lng": 98.4888673697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "03266e44fe9e208f14939d22921ed7535c791e1d",
#             "name": "Chuangtong Business Hotel",
#             "place_id": "ChIJjR0paMnUyTcROHhFlAEhJ3Q",
#             "plus_code": {
#                 "compound_code": "PFHR+86 Xifengzhen, Suzhou, Jiuquan, Gansu, China",
#                 "global_code": "8MFWPFHR+86"
#             },
#             "reference": "ChIJjR0paMnUyTcROHhFlAEhJ3Q",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "21 Mogao Road, Jiuquan"
#         }
#     ],
#     "status": "OK"
# }

# %%
#Plot the Marker layer on the gmap 
locations = [(39.73, 98.49), (38.94, 100.46), (31.80, 34.94), (33.99, 51.44), (63.84, -22.43), (41.26, 125.37), (40.06, 70.82), (31.87, 121.18), (34.77, 111.19), (27.67, 54.14)]

list_of_infoboxes = ['Hotel: Jiuquan Hotel City: jiuquan Country: CN ', 
                    'Hotel: Zhangye Lvzhou Holiday Inn City: zhangye Country: CN ',
                    'Hotel: בקתות לשקיעה City: gizo Country: IL ',
                    'Hotel: Manouchehri Traditional House And Hotel City: kashan  Country: IR ',
                    'Hotel: Northern Light Inn City: grindavik Country: IS ',
                    'Hotel: Dynasty Wunvshan Ice Chateau City: huanren Country: CN ',
                    'Hotel: Gotinitsa City: batken Country: KG ',
                    'Hotel: Home Inn City: haimen Country: CN ',
                    'Hotel: Pengzhou Hotel City: sanmenxia Country: CN ',
                    'Hotel: Chelpasin City: gerash Country: IR ']

marker_layer = gmaps.marker_layer(locations, info_box_content= list_of_infoboxes)

#, info_box_content= list_of_infoboxes)
fig.add_layer(marker_layer)

fig.add_layer(heat_layer)

# Display Map
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# # ===Don't execute below this line, just practice loops on scrap code =====

# %%
#was trying to work on this for loop but couldnt get it to work 
for index, row in hotel_df.iterrows():
    
# geocoordinates
    target_coordinates = hotel_df[["Lat", "Lng"]]
    target_radius = 5000
    target_type = "lodging"
#row_loc = 

# set up a parameters dictionary
    params = {
    "location": target_coordinates,
    "radius": target_radius,
    "type": target_type,
    "key": g_key
    }

# base url
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?"
#"https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-33.8670522,151.1957362&radius=1500&type=restaurant&keyword=cruise&key=YOUR_API_KEY"
# run a request using our params dictionary
    response = requests.get(base_url, params=params)
    places_data = response.json()
#print(json.dumps(places_data, indent=4, sort_keys=True))
    try:
        hotel_name = places_data["results"][0]["name"]
    except: 
        pass
#print(hotel_name)
#df.loc[[0,3],'Z'] = 3
    hotel_df['Hotel Name'] = hotel_name
    hotel_df.loc[[index], 'Hotel Name'] = hotel_name

hotel_df

# %%
for index, row in hotel_df.iterrows():
    # get lat, lng from df
    target_coordinates = hotel_df[["Lat", "Lng"]]
    target_radius = 5000
    target_type = "lodging"

    params = {
    "location": target_coordinates,
    "radius": target_radius,
    "type": target_type,
    "key": g_key
    }

# base url
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?"

    # make request and print url
    hotel_name = requests.get(base_url, params=params)
    
#     print the name_address url, avoid doing for public github repos in order to avoid exposing key
#     print(name_address.url)

    # convert to json
    hotel_name = hotel_name.json()
    # print(json.dumps(name_address, indent=4, sort_keys=True))

    # Since some data may be missing we incorporate a try-except to skip any that are missing a data point.
    try:
        hotel_df.loc[index, "Hotel Name"] = hotel_name["results"][0]["name"]
    except (KeyError, IndexError):
        hotel_df.loc[index, "Hotel Name"] = "Missing field/result... skipping."
hotel_df

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in narrowed_city_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]

# %%
# Add marker layer ontop of heat map
Data = {'Lat': ['-24.19'], 'Long' : ['-65.45']}
df = pd.DataFrame(Data)
#df = pd.to_numeric(df['Location'], errors='coerce')
df.astype(float)

# %%
lat = df['Lat'][0]
long = df['Long'][0]
lat

# %%
locations = [(-24.19, -65.45), (29.86, 90.73), (-34.68, -56.22), (68.75, 161.30), (-29.82, 27.24), (60.72, -46.03), (42.05, 59.39), (-16.39, -71.52), (36.20, 46.09), (60.91, -46.05), (50.11, 129.44)]
list_of_infoboxes = ['Hotel: Termas de Reyes City: guerrero negro Country: AR ', 
                    'Hotel: No Hotel City: mar del plata Country: CN ',
                    'Hotel: Villa La Alegria City: progreso Country: UY ',
                    'Hotel: No Hotel City: cherskiy  Country: RU ',
                    'Hotel: Golden Hotel City: mafeteng Country: LS ',
                    'Hotel: Hotel Qaqortoq City: qaqortoq Country: GL ',
                    'Hotel: No Hotel City: akdepe Country: TM ',
                    'Hotel: Casa de Avila Hotel City: miraflores Country: PE ',
                    'Hotel: No Hotel City: mitu Country: LU ',
                    'Hotel: Lyuks City: narsaq Country: GL ',
                    'Hotel: Lyuks City: zavitinsk Country: RU ']
marker_layer = gmaps.symbol_layer(locations, fill_color='red', info_box_content= list_of_infoboxes)
#, info_box_content= list_of_infoboxes)
fig.add_layer(marker_layer)

# Display Map
fig

#fig = gmaps.figure()


#fig.add_layer(heat_layer)

#fig
